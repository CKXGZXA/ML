# %% [markdown]
# # 第二题：使用sklearn的KMeans完成聚类
#
# 实验内容：
# 1. 使用sklearn的Kmeans完成两个数据集的聚类任务
# 2. 计算外部指标FMI和NMI
# 3. 对聚类结果可视化

# %% [markdown]
# # 1. 导入模块

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. 生成数据集

# %%
from sklearn import datasets
X1, y1 = datasets.make_circles(n_samples = 1500, factor = 0.5, noise = 0.05, random_state = 32)
X2, y2 = datasets.make_moons(n_samples = 1500, noise = 0.05, random_state = 32)

# %%
colors = np.array(['#377eb8', '#ff7f00', '#4daf4a', '#f781bf', '#a65628', '#984ea3', '#999999', '#e41a1c', '#dede00'])

# %%
plt.title('dataset1')
plt.scatter(X1[:, 0], X1[:, 1], s = 10, c = colors[y1])

# %%
plt.title('dataset2')
plt.scatter(X2[:, 0], X2[:, 1], s = 10, c = colors[y2])

# %% [markdown]
# # 3. 导入模型
#
# 我们导入KMeans模型

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# # 4. 聚类

# %%
model_1 = KMeans(n_clusters=2)
model_1.fit(X1)
# Out:
# KMeans(n_clusters=2)

# %%
model_2 = KMeans(n_clusters=2)
model_2.fit(X2)
# Out:
# KMeans(n_clusters=2)

# %% [markdown]
# 使用predict方法预测结果

# %%
model_1.predict(X1)
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int32)

# %%
model_2.predict(X2)
# Out:
# array([1, 1, 1, ..., 0, 1, 0], dtype=int32)

# %% [markdown]
# # 5. 聚类结果可视化

# %%
plt.title('dataset1')
plt.scatter(X1[:, 0], X1[:, 1], s = 10, color=colors[model_1.predict(X1)])

# %%
plt.title('dataset2')
plt.scatter(X2[:, 0], X2[:, 1], s = 10, color=colors[model_2.predict(X2)])

# %% [markdown]
# # Test
#
# 请你完成Kmeans聚类算法在两个数据集上的指标计算
#
# ###### 双击此处填写
#
# 算法|数据集|FMI|NMI
# -|-|-|-
# KMeans|数据集1|0.49950877153464884|0.00012830419257791492
# KMeans|数据集2|0.6245264042587219|0.1887663125222284

# %%
# YOUR CODE HERE
from sklearn.metrics import normalized_mutual_info_score
from sklearn.metrics import fowlkes_mallows_score


print("数据集1 NMI", normalized_mutual_info_score(y1, model_1.predict(X1)))
print("数据集2 NMI", normalized_mutual_info_score(y2, model_2.predict(X2)))
print("数据集1 FMI", fowlkes_mallows_score(y1, model_1.predict(X1)))
print("数据集2 FMI", fowlkes_mallows_score(y2, model_2.predict(X2)))
# Out:
# 数据集1 NMI 2.0520213711914244e-05
# 数据集2 NMI 0.18876631226759538
# 数据集1 FMI 0.4993627265063227
# 数据集2 FMI 0.6245264042587219
